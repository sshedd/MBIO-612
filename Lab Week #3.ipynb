# %%
install.packages("tidyverse")
library("tidyverse")
# Out:
# also installing the dependency 'jsonlite'
# package 'jsonlite' successfully unpacked and MD5 sums checked
# Warning message:
# "cannot remove prior installation of package 'jsonlite'"
# Warning message in file.copy(savedcopy, lib, recursive = TRUE):
# "problem copying C:\Users\Sam\anaconda3\envs\r-tutorial\Lib\R\library\00LOCK\jsonlite\libs\x64\jsonlite.dll to C:\Users\Sam\anaconda3\envs\r-tutorial\Lib\R\library\jsonlite\libs\x64\jsonlite.dll: Permission denied"
# Warning message:
# "restored 'jsonlite'"
# package 'tidyverse' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Sam\AppData\Local\Temp\RtmpcRGdG9\downloaded_packages
# Warning message:
# "package 'tidyverse' was built under R version 3.6.3"
# Error: package or namespace load failed for 'tidyverse' in loadNamespace(j <- i[[1L]], c(lib.loc, .libPaths()), versionCheck = vI[[j]]):
#  namespace 'jsonlite' 1.6 is already loaded, but >= 1.7.2 is required
# Traceback:
#
# 1. library("tidyverse")
# 2. tryCatch({
#  .     attr(package, "LibPath") <- which.lib.loc
#  .     ns <- loadNamespace(package, lib.loc)
#  .     env <- attachNamespace(ns, pos = pos, deps, exclude, include.only)
#  . }, error = function(e) {
#  .     P <- if (!is.null(cc <- conditionCall(e)))
#  .         paste(" in", deparse(cc)[1L])
#  .     else ""
#  .     msg <- gettextf("package or namespace load failed for %s%s:\n %s",
#  .         sQuote(package), P, conditionMessage(e))
#  .     if (logical.return)
#  .         message(paste("Error:", msg), domain = NA)
#  .     else stop(msg, call. = FALSE, domain = NA)
#  . })
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. value[[3L]](cond)
# 6. stop(msg, call. = FALSE, domain = NA)

# %%
library("ggplot2")

# %% [markdown]
# # Question 1

# %%
str(mpg)
# Out:
# tibble [234 x 11] (S3: tbl_df/tbl/data.frame)
#  $ manufacturer: chr [1:234] "audi" "audi" "audi" "audi" ...
#  $ model       : chr [1:234] "a4" "a4" "a4" "a4" ...
#  $ displ       : num [1:234] 1.8 1.8 2 2 2.8 2.8 3.1 1.8 1.8 2 ...
#  $ year        : int [1:234] 1999 1999 2008 2008 1999 1999 2008 1999 1999 2008 ...
#  $ cyl         : int [1:234] 4 4 4 4 6 6 6 4 4 4 ...
#  $ trans       : chr [1:234] "auto(l5)" "manual(m5)" "manual(m6)" "auto(av)" ...
#  $ drv         : chr [1:234] "f" "f" "f" "f" ...
#  $ cty         : int [1:234] 18 21 20 21 16 18 18 18 16 20 ...
#  $ hwy         : int [1:234] 29 29 31 30 26 26 27 26 25 28 ...
#  $ fl          : chr [1:234] "p" "p" "p" "p" ...
#  $ class       : chr [1:234] "compact" "compact" "compact" "compact" ...
# Error in count(mpg): could not find function "count"
# Traceback:

# %%
dim(mpg)
# Out:
# [1] 234  11

# %% [markdown]
# # Question 2

# %%
ggplot(data = mpg) + 
geom_point(mapping = aes(x = displ, y = hwy, color = class))
# Out:
# plot without title

# %%
ggplot(data = mpg) + 
geom_point(mapping = aes(x = displ, y = hwy), color = "blue")
# Out:
# plot without title

# %% [markdown]
# # Question 4

# %%
ggplot(mpg, mapping = aes(cty, hwy)) + 
  geom_point(mpg, mapping =aes(cty,hwy, color = class), size = 6) + 
  geom_smooth(method = lm, formula = y ~ x, mapping = aes(cty, hwy), color = "red")
# Out:
# plot without title

# %% [markdown]
# # Question 5

# %%
mpg_subcompact_subset = mpg[which(mpg$class=="subcompact"),]
  mpg_subcompact_subset_15 = mpg_subcompact_subset[which(mpg_subcompact_subset$cty == 15),]
  print(mpg_subcompact_subset_15)
# Out:
# # A tibble: 4 x 11
#   manufacturer model   displ  year   cyl trans   drv     cty   hwy fl    class
#   <chr>        <chr>   <dbl> <int> <int> <chr>   <chr> <int> <int> <chr> <chr>
# 1 ford         mustang   4.6  1999     8 auto(l~ r        15    21 r     subcom~
# 2 ford         mustang   4.6  1999     8 manual~ r        15    22 r     subcom~
# 3 ford         mustang   4.6  2008     8 manual~ r        15    23 r     subcom~
# 4 ford         mustang   4.6  2008     8 auto(l~ r        15    22 r     subcom~

# %%
sub_15 <- which(mpg$cty == 15 & mpg$class == "subcompact")

# %%
mpg[sub_15,c("manufacturer","model")]
# Out:
#   manufacturer model
# 1 ford         mustang
# 2 ford         mustang
# 3 ford         mustang
# 4 ford         mustang

# %% [markdown]
# # Question 6

# %%
ggplot(data = mpg) + 
        geom_point(mapping = aes(x = displ, y = hwy, shape = class))+
        scale_shape_manual(values = c(0,1,2,3,4,5,6))
# Out:
# plot without title

# %% [markdown]
# # Question 7

# %%
x <- c(3.385,0.48,1.35,465,36.33,27.66,14.83,1.04,4.19,0.425,0.101,0.92,1,0.005,0.06,3.5,2,1.7,2547,0.023,187.1,521,0.785,10,3.3,0.2,1.41,529,207,85,0.75,62,6654,3.5,6.8,35,4.05,0.12,0.023,0.01,1.4,250,2.5,55.5,100,52.16,10.55,0.55,60,3.6,4.288,0.28,0.075,0.122,0.048,192,3,160,0.9,1.62,0.104,4.235)
y <- c(44.5,15.5,8.1,423,119.5,115,98.2,5.5,58,6.4,4,5.7,6.6,0.14,1,10.8,12.3,6.3,4603,0.3,419,655,3.5,115,25.6,5,17.5,680,406,325,12.3,1320,5712,3.9,179,56,17,1,0.4,0.25,12.5,490,12.1,175,157,440,179.5,2.4,81,21,39.2,1.9,1.2,3,0.33,180,25,169,2.6,11.4,2.5,50.4)

# %%
sizeMass <- data.frame(x,y)
colnames(sizeMass) <- c("size", "mass")

# %%
gplot(sizeMass, aes(size, mass)) +
  geom_point() +
  geom_smooth(method = "lm", color = "red", se = FALSE)
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %% [markdown]
# # Question 8

# %%
log_sizeMass <- log10(sizeMass)
colnames(log_sizeMass) <- c("size_log10", "mass_log")

# %%
ggplot(log_sizeMass, aes(size_log10, mass_log)) +
  geom_point() +
  geom_smooth(method = "lm", color = "red", se = FALSE)
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title

# %%
ggplot(sizeMass, aes(size,mass)) +
  scale_x_log10() +
  scale_y_log10() +
  geom_point() +
  geom_smooth(method = "lm", color = "red", se = FALSE)
# Out:
# `geom_smooth()` using formula 'y ~ x'
# plot without title
